# %%
import numpy as np
from src.task2 import *
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline

# %%
alpha = np.linspace(-2, 8, num = 100)

# %%
bifurcation_plot(first_equation, alpha, r'$\dot{x} = \alpha - x^2$')

# %%
phase_portrait_plot(alpha=0, system_id=1)

# %%
bifurcation_plot(second_equation, alpha, r'$\dot{x} = \alpha - 2x^2 - 3$')

# %%
phase_portrait_plot(alpha=5, system_id=2)
