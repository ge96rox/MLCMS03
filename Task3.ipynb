# %% [markdown]
# # Task3

# %%
from src.task3 import *

# %load_ext autoreload
# %autoreload 2
# %matplotlib inline

# %% [markdown]
# ## Task3.1 Andronov_Hopf Bifurcation

# %%
alpha = -1.8
plot_phase_potrait_Andronov_Hopf(alpha)

# %%
alpha = 0
plot_phase_potrait_Andronov_Hopf(alpha)

# %%
alpha = 1.3
plot_phase_potrait_Andronov_Hopf(alpha)

# %% [markdown]
# ## Task3.2 Orbits along Time

# %%
plot_orbit_with_time([2,0])

# %%
plot_orbit_with_time([0.5,0])

# %% [markdown]
# ## Task3.3 Cusp bifurcation

# %%
plot_bifurcation_surface_cusp(view_angle=(30,60))
