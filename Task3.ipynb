# %% [markdown]
# # Task3

# %%
from src.task3 import *

# %load_ext autoreload
# %autoreload 2
# %matplotlib inline

# %% [markdown]
# ## Task3.1 Andronov_Hopf Bifurcation

# %%
alpha = -1.8
plot_phase_potrait_Andronov_Hopf(alpha)

# %%
alpha = 0
plot_phase_potrait_Andronov_Hopf(alpha)

# %%
alpha = 1.3
plot_phase_potrait_Andronov_Hopf(alpha)
