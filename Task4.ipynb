# %%
from src.task4 import *
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
r_range = [0, 4]
x_range = [0, 1]

plot_logistic_map_bifurcation(r_range, x_range, resolution=100, iteration=100)

# %%
rho = 28
sigma = 10
beta = 8./3
y0_list = [[10, 10, 10], [10 + 10 ** -8, 10, 10]]
plot_lorenz_burfication(y0_list, rho, sigma, beta)

# %%
rho = 0.5
sigma = 10
beta = 8./3
y0_list = [[10, 10, 10], [10 + 10 ** -8, 10, 10]]
plot_lorenz_burfication(y0_list, rho, sigma, beta)
