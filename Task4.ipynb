# %%
from src.task4 import *
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
r_range = [0, 4]
x_range = [0, 1]
plot_logistic_map_bifurcation(r_range, x_range, resolution=1000, iteration=1000, save=False)

# %%
r_range = [0, 2]
x_range = [0, 1]
plot_logistic_map_bifurcation(r_range, x_range, resolution=10000, iteration=1000, save=False)

# %%
r_range = [2, 4]
x_range = [0, 1]
plot_logistic_map_bifurcation(r_range, x_range, resolution=10000, iteration=1000, save=False)

# %%
r_values = [0.5,1,1.5,2.5,3,3.5,3.7]

plot_logistic_map_simulation(r_values, save=False)

# %%
rho = 28
sigma = 10
beta = 8./3
y0_list = [[10, 10, 10], [10 + 10 ** -8, 10, 10]]

simulation_time = 1000
resolution = 30000
plot_lorenz_burfication(y0_list, rho, sigma, beta, simulation_time, resolution, save=False)
# Out:
# since time point 25, the difference between the points on the trajectory larger than 1

# %%
rho = np.linspace(0.5, 28, 5)
sigma = 10
beta = 8./3
y0_list = [[10, 10, 10], [10 + 10 ** -8, 10, 10]]

simulation_time = 1000
resolution = 30000
for rho_l in rho:
    plot_lorenz_burfication(y0_list, rho_l, sigma, beta, simulation_time, resolution, save=False)
# Out:
# there does not exist a time point, since then the distance between points larger than 1
# there does not exist a time point, since then the distance between points larger than 1
# there does not exist a time point, since then the distance between points larger than 1
# there does not exist a time point, since then the distance between points larger than 1
# since time point 25, the difference between the points on the trajectory larger than 1
