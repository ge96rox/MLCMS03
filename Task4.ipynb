# %%
from src.task4 import *
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
r_range = [0, 4]

plot_logistic_map_bifurcation(r_range, resolution=1000, iteration=1000)

# %%
rho = 28
sigma = 10
beta = 8./3
y0_list = [[10, 10, 10], [10 + 10 ** -8, 10, 10]]
plot_lorenz_burfication(y0_list, rho, sigma, beta)

# %%
rho = np.linspace(0.5, 28, 5)
sigma = 10
beta = 8./3
y0_list = [[10, 10, 10], [10 + 10 ** -8, 10, 10]]
for rho_l in rho:
    plot_lorenz_burfication(y0_list, rho_l, sigma, beta)

# %%
r_values = [0.5,1,1.5,2.5,3,3.5,3.7]

plot_logistic_map_simulation(r_values)
