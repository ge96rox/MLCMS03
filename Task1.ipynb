# %% [markdown]
# # Task1

# %%
from src.task1 import *

# %load_ext autoreload
# %autoreload 2
# %matplotlib inline

# %% [markdown]
# ## Unstable focus
#
# A = \begin{pmatrix}
# 0.1 & 0.1 \\
# -0.25 & 0
# \end{pmatrix}
#
# with eigenvalues $\lambda$_1 = 0.05+0.15j and $\lambda$_2=0.05-0.15j

# %%
initial_pts = [[0,0], [0,-0.25],[0,0.25]]
 
alpha = 0.1
A = np.array([[alpha,alpha],[-0.25,0]])   
plot_phase_potrait(A,initial_pts)

# %% [markdown]
# ## Stable focus
#
# A = \begin{pmatrix}
# -0.1 & -0.1 \\
# 0.25 & 0
# \end{pmatrix}
#
# with eigenvalues $\lambda$_1 = -0.05+0.15j and $\lambda$_2=-0.05-0.15j

# %%
initial_pts = [[0,0], [0,-0.25],[0,0.25]]
 
alpha = -0.1
A = np.array([[alpha,alpha],[0.25,0]])   
plot_phase_potrait(A,initial_pts)

# %% [markdown]
# ## Unstable node
#
# A = \begin{pmatrix}
# 1 & 0 \\
# 0 & 2
# \end{pmatrix}
#
# with eigenvalues $\lambda$_1 = 1 and $\lambda$_2=2

# %%
initial_pts = [[-1,0],[-0.5,0.5],[0,1],[0.5,0.5],[1,0],[-0.5,-0.5],[0,-1],[0.5,-0.5]]
A = np.array([[1,0],[0,2]])   
plot_phase_potrait(A,initial_pts)

# %% [markdown]
# ## Stable node
#
# A = \begin{pmatrix}
# -1 & 0 \\
# 0 & -2
# \end{pmatrix}
#
# with eigenvalues $\lambda$_1 = -1 and $\lambda$_2=-2

# %%
initial_pts = [[-1,0],[-0.5,0.5],[0,1],[0.5,0.5],[1,0],[-0.5,-0.5],[0,-1],[0.5,-0.5]]
A = np.array([[-1,0],[0,-2]])   
plot_phase_potrait(A,initial_pts)

# %% [markdown]
# ## Saddle
#
# A = \begin{pmatrix}
# -1 & 0 \\
# 0 & 2
# \end{pmatrix}
#
# with eigenvalues $\lambda$_1 = -1 and $\lambda$_2=2

# %%
initial_pts = [[-1,0],[-0.5,0.5],[0,1],[0.5,0.5],[1,0],[-0.5,-0.5],[0,-1],[0.5,-0.5]]
A = np.array([[-1,0],[0,2]])   
plot_phase_potrait(A,initial_pts)
